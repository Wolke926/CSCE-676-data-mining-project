# %% [markdown]
# # H&M recommendation system  Project

# %% [markdown]
# ## 1.Motivation and clear Question

# %% [markdown]
# Online fashion platforms such as H&M offer thousands of products, making it difficult for customers to quickly find items they actually want. Personalized recommendation systems help solve this problem by suggesting products that match each customer’s interests and shopping history. In this project, we use H&M transaction data to explore how past purchases and product information can be used to generate useful recommendations. Our goal is to understand customer preferences and design a system that can make more relevant and personalized suggestions.
#
# Question: How can we use historical purchase data and product information to recommend the most relevant items to each H&M customer?
#
# Task:
# Given users’ historical purchase behaviors and static user/item attributes, the goal is to predict the top 12 items each test user is most likely to purchase in a future 7 days time window.
# Evaluation: MAP@K
#
# Data from Kaggle: https://www.kaggle.com/competitions/h-and-m-personalized-fashion-recommendations

# %% [markdown]
# ## 2. Data Preparation

# %% [markdown]
# ### 2.1 Data Loading and Analysis

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from tqdm import tqdm

# %%
from pathlib import Path

path = 'data/'
art = f'{path}articles.csv'
cus = f'{path}customers.csv'
tran = f'{path}transactions_train.csv'
sub_path = f'{path}sample_submission.csv'

# %%
df = pd.read_csv(tran, dtype= {'customer_id':str, 'article_id':str}, parse_dates = ['t_dat'])
df_art = pd.read_csv(art, dtype = {'article_id':str})
df_cus = pd.read_csv(cus, dtype= {'customer_id':str})
df_sub = pd.read_csv(sub_path, dtype = {'customer_id':str})
df.head(5)
# Out:
#        t_dat                                        customer_id  article_id  \
# 0 2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  0663713001
# 1 2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  0541518023
# 2 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  0505221004
# 3 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  0685687003
# 4 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  0685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %%
df.shape
# Out:
# (31788324, 5)

# %%
df_cus.head(3)

# %%
df_art.head(3)
# Out:
#    article_id  product_code      prod_name  product_type_no product_type_name  \
# 0  0108775015        108775      Strap top              253          Vest top
# 1  0108775044        108775      Strap top              253          Vest top
# 2  0108775051        108775  Strap top (1)              253          Vest top
#
#    product_group_name  graphical_appearance_no graphical_appearance_name  \
# 0  Garment Upper body                  1010016                     Solid
# 1  Garment Upper body                  1010016                     Solid
# 2  Garment Upper body                  1010017                    Stripe
#
#    colour_group_code colour_group_name  ...  department_name index_code  \
# 0                  9             Black  ...     Jersey Basic          A
# 1                 10             White  ...     Jersey Basic          A
# 2                 11         Off White  ...     Jersey Basic          A
#
#    index_name index_group_no  index_group_name section_no  \
# 0  Ladieswear              1        Ladieswear         16
# 1  Ladieswear              1        Ladieswear         16
# 2  Ladieswear              1        Ladieswear         16
#
#              section_name garment_group_no  garment_group_name  \
# 0  Womens Everyday Basics             1002        Jersey Basic
# 1  Womens Everyday Basics             1002        Jersey Basic
# 2  Womens Everyday Basics             1002        Jersey Basic
#
#                                detail_desc
# 0  Jersey top with narrow shoulder straps.
# 1  Jersey top with narrow shoulder straps.
# 2  Jersey top with narrow shoulder straps.
#
# [3 rows x 25 columns]

# %%
'''
mapping IDs. It is necessary because many recommendation system models 
(such as matrix factorization, embeddings, and neural networks) require user IDs and item IDs 
to be represented as continuous integer indices starting from 0, with no gaps.

'''
ALL_CUSTOMERS = df_cus['customer_id'].drop_duplicates().tolist()
ALL_ARTICLES = df_art['article_id'].drop_duplicates().tolist()

CUSTOMER_TO_USER = {cus: u for u, cus in enumerate(ALL_CUSTOMERS)}
USER_TO_CUSTOMER = {u: cus for u, cus in enumerate(ALL_CUSTOMERS)}

ARTICLE_TO_ITEM = {art: i for i, art in enumerate(ALL_ARTICLES)}
ITEM_TO_ARTICLE = {i: art for i, art in enumerate(ALL_ARTICLES)}

df['user_id'] = df['customer_id'].map(CUSTOMER_TO_USER).astype('int32')
df['item_id'] = df['article_id'].map(ARTICLE_TO_ITEM).astype('int32')

df_sub['user_id'] = df_sub['customer_id'].map(CUSTOMER_TO_USER).astype('int32')

# %%
num_users = len(CUSTOMER_TO_USER)
num_items = len(ARTICLE_TO_ITEM)
print(f"num of users = {num_users},num of items = {num_items}")
# Out:
# num of users = 1371980,num of items = 105542

# %%
df.head(3)
# Out:
#        t_dat                                        customer_id  article_id  \
# 0 2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  0663713001
# 1 2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  0541518023
# 2 2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...  0505221004
#
#       price  sales_channel_id  user_id  item_id
# 0  0.050831                 2        2    40179
# 1  0.030492                 2        2    10520
# 2  0.015237                 2        7     6387

# %%
## Are The customers long-tail? most of them only buy few articles.
user_cnt = df.groupby('customer_id').size()
user_cnt.describe() 
# while many users have limited purchase histories, a substantial portion of users have sufficient interactions to support personalized recommendations.#User purchase behavior is moderately long-tailed
# Out:
# count    1.362281e+06
# mean     2.333463e+01
# std      3.924225e+01
# min      1.000000e+00
# 25%      3.000000e+00
# 50%      9.000000e+00
# 75%      2.700000e+01
# max      1.895000e+03
# dtype: float64

# %%
item_cnt = df.groupby(['article_id']).size()
item_cnt.describe()
 #Item popularity is extremely long-tailed.
# Out:
# count    104547.000000
# mean        304.057735
# std         791.266060
# min           1.000000
# 25%          14.000000
# 50%          65.000000
# 75%         286.000000
# max       50287.000000
# dtype: float64

# %%
last_day = df['t_dat'].max()
last_week_day = last_day.weekday()
first_day = df['t_dat'].min()
first_week_day = first_day.weekday()
print(f'The last day in the data set is {last_day},It is a {last_week_day} weekday')
print(f'The last day in the data set is {first_day},It is a {first_week_day} weekday')

# The last day in our list is 2020-09-22, this is a Tuesday. We are using Monday as the start day for every week.
FIRST_DAY_OF_LAST_WEEK = last_day - pd.Timedelta(days = 6)
print(FIRST_DAY_OF_LAST_WEEK)
#a week is defined as [first day , last day)
# Out:
# The last day in the data set is 2020-09-22 00:00:00,It is a 1 weekday
# The last day in the data set is 2018-09-20 00:00:00,It is a 3 weekday
# 2020-09-16 00:00:00

# %% [markdown]
# ### 2.2 itemcf recall

# %%
import math
import pandas as pd
import numpy as np
from collections import defaultdict
from tqdm import tqdm

def time_decay(delta_days, half_life=7):
    return 0.5 ** (delta_days / half_life)

# %%
def itemcf(history_df,
    topk=50,max_user_items=20,item_sim_topk=100,
    start_date=None,user_col="user_id",item_col="item_id",date_col="t_dat",):
    hist = history_df.copy()
    hist[date_col] = pd.to_datetime(hist[date_col])

    # 可选：只用最近一段历史，减少计算量
    if start_date is not None:
        hist = hist[hist[date_col] > pd.to_datetime(start_date)]

    hist = hist.sort_values([user_col, date_col, item_col])

    user_item_time = (
        hist.groupby(user_col)[[item_col, date_col]]
        .apply(lambda x: list(zip(x[item_col], x[date_col]))[-max_user_items:])
    )
    item_sim = defaultdict(lambda: defaultdict(float))
    item_cnt = defaultdict(int)

    # 1. build item-item similarity
    for u, item_time_list in tqdm(user_item_time.items(), desc="Build ItemCF"):
        items = [i for i, _ in item_time_list]
        times = [t for _, t in item_time_list]
        L = len(items)

        for i in range(L):
            item_i = items[i]
            time_i = times[i]
            item_cnt[item_i] += 1

            for j in range(L):
                if i == j:
                    continue

                item_j = items[j]
                time_j = times[j]

                if item_i == item_j:
                    continue

                delta = abs((time_i - time_j).days)

                loc_weight = 1.0 / (1 + abs(i - j))

                # the more recent, we should give more weight
                decay_weight = time_decay(delta)

                item_sim[item_i][item_j] += loc_weight * decay_weight

    for i, related_items in item_sim.items():
        for j in related_items:
            item_sim[i][j] /= math.sqrt(item_cnt[i] * item_cnt[j])

    # 3. keep topk similar items for each item
    item_sim = {
        i: dict(sorted(related.items(), key=lambda x: x[1], reverse=True)[:item_sim_topk])
        for i, related in item_sim.items()
    }

    # 4. recall candidates for each user
    rows = []
    for u, item_time_list in tqdm(user_item_time.items(), desc="Recall ItemCF"):
        user_items = [i for i, _ in item_time_list]
        scores = defaultdict(float)

        for item in user_items:
            if item not in item_sim:
                continue

            for j, sim in item_sim[item].items():
                scores[j] += sim

        rec_items = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:topk]

        for item_id, score in rec_items:
            rows.append([u, item_id, score])

    cand = pd.DataFrame(rows, columns=[user_col, item_col, "score"])

    return cand

# %%
df["t_dat"] = pd.to_datetime(df["t_dat"])

TRAIN_WEEKS = 7
VALID_WEEKS = 1

last_day = df["t_dat"].max()

valid_week_start = last_day - pd.Timedelta(days=6)

train_week_start = valid_week_start - pd.Timedelta(weeks=TRAIN_WEEKS)

df_small = df[df["t_dat"] >= train_week_start].copy()

print("last_day:", last_day)
print("valid_week_start:", valid_week_start)
print("train_week_start:", train_week_start)
print(df_small["t_dat"].min(), df_small["t_dat"].max())
# Out:
# last_day: 2020-09-22 00:00:00
# valid_week_start: 2020-09-16 00:00:00
# train_week_start: 2020-07-29 00:00:00
# 2020-07-29 00:00:00 2020-09-22 00:00:00

# %% [markdown]
# #### 2.3. Training data split and preparation

# %% [markdown]
# After we use User-CF to generate some candidates. We should divide the data into several weeks, create a label for each week for our neural network training in the following steps, 1 means (user, item) candidate hits the prediction. Use the previous week to predict the next week. The last week is the validation dataset.

# %%
def gen_train_valid(df, n_windows, n_neg, itemcf, valid_start_date):
    df = df.copy()
    df["t_dat"] = pd.to_datetime(df["t_dat"])
    df = df.sort_values(["t_dat", "user_id", "item_id"])

    valid_start_date = pd.to_datetime(valid_start_date)
    all_items = df["item_id"].unique()
    rng = np.random.default_rng(42)

    train_list = []
    valid_list = []
    for i in range(n_windows + 1):
        # i = 0 valid, i > 0 train
        label_start = valid_start_date - pd.Timedelta(days=7 * i)
        label_end = label_start + pd.Timedelta(days=7)

        label_df = df[(df["t_dat"] >= label_start) &(df["t_dat"] < label_end)]

        history_df = df[df["t_dat"] < label_start]

        # pos samples
        pos = label_df[["user_id", "item_id"]].drop_duplicates()
        pos["label"] = 1
        pos["window"] = i

        # cancidates：use history to make itemcf recall
        cand = (itemcf(history_df)[["user_id", "item_id", "score"]].drop_duplicates(["user_id", "item_id"]).reset_index(drop=True))

        # neg samples:recall but not bought in next week
        pos_pairs = set(zip(pos["user_id"], pos["item_id"]))
        cand["_pair"] = list(zip(cand["user_id"], cand["item_id"]))
        neg_pool = cand[~cand["_pair"].isin(pos_pairs)].drop(columns="_pair")
        neg_list = []
        for u, g in pos.groupby("user_id"):
            k = len(g) * n_neg

            user_neg = neg_pool[neg_pool["user_id"] == u]["item_id"].unique()

            if len(user_neg) >= k:
                neg_items = rng.choice(user_neg, size=k, replace=False)
            else:
                neg_items = list(user_neg)

                bought = set(g["item_id"])
                while len(neg_items) < k:
                    item = rng.choice(all_items)
                    if item not in bought and item not in neg_items:
                        neg_items.append(item)

            for item in neg_items:
                neg_list.append([u, item, 0, i])
        neg = pd.DataFrame(
            neg_list,
            columns=["user_id", "item_id", "label", "window"])

        samples = pd.concat([pos, neg], ignore_index=True)

        if i == 0:
            valid_list.append(samples)
        else:
            train_list.append(samples)

    train_df = pd.concat(train_list, ignore_index=True)
    valid_df = pd.concat(valid_list, ignore_index=True)

    X_train = train_df[["user_id", "item_id", "window"]]
    y_train = train_df["label"]

    X_valid = valid_df[["user_id", "item_id", "window"]]
    y_valid = valid_df["label"]

    return X_train, y_train, X_valid, y_valid

# %%
X_train, y_train, X_valid, y_valid = gen_train_valid(df = df_small,n_windows=2,n_neg=5,itemcf=itemcf,valid_start_date=valid_week_start)
# Out:
# Build ItemCF: 350008it [00:11, 29836.43it/s]
# Recall ItemCF: 350008it [00:28, 12156.26it/s]
# Build ItemCF: 317672it [00:09, 32187.62it/s]
# Recall ItemCF: 317672it [00:25, 12408.95it/s]
# Build ItemCF: 279667it [00:07, 35111.97it/s]
# Recall ItemCF: 279667it [00:27, 10164.58it/s]

# %%
train_samples = X_train.copy()
train_samples["label"] = y_train.values

valid_samples = X_valid.copy()
valid_samples["label"] = y_valid.values

train_samples.to_parquet("train_samples.parquet", index=False)
valid_samples.to_parquet("valid_samples.parquet", index=False)

# %%
train_samples = pd.read_parquet("train_samples.parquet")
valid_samples = pd.read_parquet("valid_samples.parquet")

# %%
X_train = train_samples[["user_id", "item_id"]].values.astype("int32")
X_valid = valid_samples[["user_id", "item_id"]].values.astype("int32")

y_train = train_samples["label"].values.astype("float32")
y_valid = valid_samples["label"].values.astype("float32")

# %%
print(train_samples.sample(6))
# Out:
#          user_id  item_id  window  label
# 1190966  1159336    57401       1      0
# 1908834   343717    73507       2      0
# 1647080    46033    55727       2      0
# 168961    968431   104700       1      1
# 150936    266332    77256       1      1
# 2253196   743910    78247       2      0

# %% [markdown]
# ## 3.1 Recall

# %% [markdown]
# We use item-based collaborative filtering because item-item relationships are usually more stable and reliable in retail recommendation. In our setting, there are many users and the interaction matrix is sparse, so itemCF is often more practical than userCF. The core idea of itemCF is to recommend items that are similar to the items a user has interacted with before. If two items are frequently purchased by the same users, they are considered similar, and those similar items can be used as candidates for recommendation.
# The function has been listed above

# %% [markdown]
# ## 3.2 Ranking

# %% [markdown]
# ### 3.2.1 Word2Vec

# %%
import pickle
from tqdm import tqdm
import sys
from pathlib import Path
from gensim.models import Word2Vec
import pandas as pd
import numpy as np
from sklearn.preprocessing import normalize

model_dir = Path("models")
data_dir = Path('data')
embd = Path('embd')
valid_start = '2020-09-16'
#we use the samples before the first day of valid_data as training data for our embeddings to avoid data leakage

# %%
embd_data = df_small.copy()
embd_data['t_dat'] = pd.to_datetime(embd_data['t_dat'], errors='coerce')
embd_data = embd_data.dropna(subset=['user_id', 'item_id', 't_dat'])
# embd_data is the last 8-1 weeks transactions
embd_data = embd_data[(embd_data['t_dat'] < valid_start)].copy()
embd_data.shape
# Out:
# (1933564, 7)

# %%
# Output 1: item-embd (skip-gram), user-embd is the average of item embd
import logging
from gensim.models import Word2Vec

#should sort first, sequence is important
inter = embd_data.sort_values(['user_id','t_dat','item_id']).reset_index(drop = True)

#every sentence is a list of articles for every customer,use skip-gram to calculate embd for every article
seq_list = inter.groupby(['user_id'])['item_id'].apply(lambda x: [str(id) for id in x]).to_list()
#sg=1 skip-gram, sg = 0, cbow
logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s',
    level=logging.INFO)
model_sg = Word2Vec(seq_list, vector_size = 128, window = 32, min_count = 1, sg = 1, sample = 1e-3, negative = 15,workers=8,seed = 1,epochs = 5)
model_sg.save(str(model_dir/'item_id_sg_model.model'))
# Out:
# 2026-04-26 11:51:00,177 : INFO : collecting all words and their counts
# 2026-04-26 11:51:00,177 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2026-04-26 11:51:00,182 : INFO : PROGRESS: at sentence #10000, processed 56448 words, keeping 12877 word types
# 2026-04-26 11:51:00,186 : INFO : PROGRESS: at sentence #20000, processed 112222 words, keeping 16514 word types
# 2026-04-26 11:51:00,190 : INFO : PROGRESS: at sentence #30000, processed 168850 words, keeping 18991 word types
# 2026-04-26 11:51:00,194 : INFO : PROGRESS: at sentence #40000, processed 224548 words, keeping 20772 word types
# 2026-04-26 11:51:00,198 : INFO : PROGRESS: at sentence #50000, processed 279536 words, keeping 22160 word types
# 2026-04-26 11:51:00,202 : INFO : PROGRESS: at sentence #60000, processed 334472 words, keeping 23208 word types
# 2026-04-26 11:51:00,206 : INFO : PROGRESS: at sentence #70000, processed 389088 words, keeping 24127 word types
# 2026-04-26 11:51:00,210 : INFO : PROGRESS: at sentence #80000, processed 444160 words, keeping 24967 word types
# 2026-04-26 11:51:00,214 : INFO : PROGRESS: at sentence #90000, processed 498782 words, keeping 25740 word types
# 2026-04-26 11:51:00,218 : INFO : PROGRESS: at sentence #100000, processed 553704 words, keeping 26393 word types
# 2026-04-26 11:51:00,222 : INFO : PROGRESS: at sentence #110000, processed 608629 words, keeping 26991 word types
# 2026-04-26 11:51:00,226 : INFO : PROGRESS: at sentence #120000, processed 663717 words, keeping 27530 word types
# 2026-04-26 11:51:00,230 : INFO : PROGRESS: at sentence #130000, processed 718354 words, keeping 28098 word types
# 2026-04-26 11:51:00,234 : INFO : PROGRESS: at sentence #140000, processed 774169 words, keeping 28552 word types
# 2026-04-26 11:51:00,238 : INFO : PROGRESS: at sentence #150000, processed 829329 words, keeping 28957 word types
# 2026-04-26 11:51:00,243 : INFO : PROGRESS: at sentence #160000, processed 884346 words, keeping 29358 word types
# 2026-04-26 11:51:00,247 : INFO : PROGRESS: at sentence #170000, processed 940466 words, keeping 29761 word types
# 2026-04-26 11:51:00,251 : INFO : PROGRESS: at sentence #180000, processed 996186 words, keeping 30142 word types
# 2026-04-26 11:51:00,256 : INFO : PROGRESS: at sentence #190000, processed 1052114 words, keeping 30489 word types
# 2026-04-26 11:51:00,260 : INFO : PROGRESS: at sentence #200000, processed 1108226 words, keeping 30874 word types
# 2026-04-26 11:51:00,264 : INFO : PROGRESS: at sentence #210000, processed 1164815 words, keeping 31218 word types
# 2026-04-26 11:51:00,269 : INFO : PROGRESS: at sentence #220000, processed 1219968 words, keeping 31581 word types
# 2026-04-26 11:51:00,274 : INFO : PROGRESS: at sentence #230000, processed 1274441 words, keeping 31875 word types
# 2026-04-26 11:51:00,278 : INFO : PROGRESS: at sentence #240000, processed 1328787 words, keeping 32100 word types
# 2026-04-26 11:51:00,283 : INFO : PROGRESS: at sentence #250000, processed 1383604 words, keeping 32371 word types
# 2026-04-26 11:51:00,287 : INFO : PROGRESS: at sentence #260000, processed 1438370 words, keeping 32622 word types
# 2026-04-26 11:51:00,291 : INFO : PROGRESS: at sentence #270000, processed 1493956 words, keeping 32860 word types
# 2026-04-26 11:51:00,296 : INFO : PROGRESS: at sentence #280000, processed 1548461 words, keeping 33070 word types
# 2026-04-26 11:51:00,301 : INFO : PROGRESS: at sentence #290000, processed 1602690 words, keeping 33304 word types
# 2026-04-26 11:51:00,305 : INFO : PROGRESS: at sentence #300000, processed 1658877 words, keeping 33547 word types
# 2026-04-26 11:51:00,309 : INFO : PROGRESS: at sentence #310000, processed 1713266 words, keeping 33734 word types
# 2026-04-26 11:51:00,314 : INFO : PROGRESS: at sentence #320000, processed 1768652 words, keeping 33931 word types
# 2026-04-26 11:51:00,319 : INFO : PROGRESS: at sentence #330000, processed 1823954 words, keeping 34105 word types
# 2026-04-26 11:51:00,324 : INFO : PROGRESS: at sentence #340000, processed 1879066 words, keeping 34282 word types
# 2026-04-26 11:51:00,328 : INFO : PROGRESS: at sentence #350000, processed 1933508 words, keeping 34469 word types
# 2026-04-26 11:51:00,328 : INFO : collected 34469 word types from a corpus of 1933564 raw words and 350008 sentences
# 2026-04-26 11:51:00,329 : INFO : Creating a fresh vocabulary
# 2026-04-26 11:51:00,358 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 34469 unique words (100.00% of original 34469, drops 0)', 'datetime': '2026-04-26T11:51:00.358799', 'gensim': '4.3.3', 'python': '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-04-26 11:51:00,359 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 1933564 word corpus (100.00% of original 1933564, drops 0)', 'datetime': '2026-04-26T11:51:00.359100', 'gensim': '4.3.3', 'python': '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-04-26 11:51:00,401 : INFO : deleting the raw counts dictionary of 34469 items
# 2026-04-26 11:51:00,402 : INFO : sample=0.001 downsamples 0 most-common words
# 2026-04-26 11:51:00,402 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1933564 word corpus (100.0%% of prior 1933564)', 'datetime': '2026-04-26T11:51:00.402295', 'gensim': '4.3.3', 'python': '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2026-04-26 11:51:00,469 : INFO : estimated required memory for 34469 words and 128 dimensions: 52530756 bytes
# 2026-04-26 11:51:00,470 : INFO : resetting layer weights
# 2026-04-26 11:51:00,478 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2026-04-26T11:51:00.478907', 'gensim': '4.3.3', 'python': '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'build_vocab'}
# 2026-04-26 11:51:00,479 : INFO : Word2Vec lifecycle event {'msg': 'training model with 8 workers on 34469 vocabulary and 128 features, using sg=1 hs=0 sample=0.001 negative=15 window=32 shrink_windows=True', 'datetime': '2026-04-26T11:51:00.479115', 'gensim': '4.3.3', 'python': '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'train'}
# 2026-04-26 11:51:01,492 : INFO : EPOCH 0 - PROGRESS: at 17.44% examples, 338964 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:02,556 : INFO : EPOCH 0 - PROGRESS: at 41.82% examples, 391692 words/s, in_qsize 16, out_qsize 0
# 2026-04-26 11:51:03,580 : INFO : EPOCH 0 - PROGRESS: at 64.40% examples, 404150 words/s, in_qsize 16, out_qsize 0
# 2026-04-26 11:51:04,604 : INFO : EPOCH 0 - PROGRESS: at 87.82% examples, 412833 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:05,071 : INFO : EPOCH 0: training on 1933564 raw words (1933564 effective words) took 4.6s, 422015 effective words/s
# 2026-04-26 11:51:06,149 : INFO : EPOCH 1 - PROGRESS: at 21.07% examples, 382854 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:07,236 : INFO : EPOCH 1 - PROGRESS: at 45.98% examples, 412314 words/s, in_qsize 16, out_qsize 0
# 2026-04-26 11:51:08,275 : INFO : EPOCH 1 - PROGRESS: at 66.51% examples, 403450 words/s, in_qsize 16, out_qsize 0
# 2026-04-26 11:51:09,344 : INFO : EPOCH 1 - PROGRESS: at 91.44% examples, 414689 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:09,658 : INFO : EPOCH 1: training on 1933564 raw words (1933564 effective words) took 4.6s, 422229 effective words/s
# 2026-04-26 11:51:10,751 : INFO : EPOCH 2 - PROGRESS: at 21.07% examples, 377556 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:11,778 : INFO : EPOCH 2 - PROGRESS: at 45.45% examples, 416391 words/s, in_qsize 16, out_qsize 0
# 2026-04-26 11:51:12,781 : INFO : EPOCH 2 - PROGRESS: at 66.51% examples, 413838 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:13,781 : INFO : EPOCH 2 - PROGRESS: at 89.88% examples, 422490 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:14,226 : INFO : EPOCH 2: training on 1933564 raw words (1933564 effective words) took 4.6s, 423995 effective words/s
# 2026-04-26 11:51:15,257 : INFO : EPOCH 3 - PROGRESS: at 19.52% examples, 371286 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:16,313 : INFO : EPOCH 3 - PROGRESS: at 41.82% examples, 389342 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:17,313 : INFO : EPOCH 3 - PROGRESS: at 63.90% examples, 402410 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:18,396 : INFO : EPOCH 3 - PROGRESS: at 87.31% examples, 405745 words/s, in_qsize 16, out_qsize 0
# 2026-04-26 11:51:18,913 : INFO : EPOCH 3: training on 1933564 raw words (1933564 effective words) took 4.7s, 413181 effective words/s
# 2026-04-26 11:51:19,926 : INFO : EPOCH 4 - PROGRESS: at 19.52% examples, 377748 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:20,938 : INFO : EPOCH 4 - PROGRESS: at 40.79% examples, 391383 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:21,945 : INFO : EPOCH 4 - PROGRESS: at 61.30% examples, 393261 words/s, in_qsize 15, out_qsize 0
# 2026-04-26 11:51:22,951 : INFO : EPOCH 4 - PROGRESS: at 82.66% examples, 396728 words/s, in_qsize 16, out_qsize 0
# 2026-04-26 11:51:23,685 : INFO : EPOCH 4: training on 1933564 raw words (1933564 effective words) took 4.8s, 405855 effective words/s
# 2026-04-26 11:51:23,686 : INFO : Word2Vec lifecycle event {'msg': 'training on 9667820 raw words (9667820 effective words) took 23.2s, 416598 effective words/s', 'datetime': '2026-04-26T11:51:23.686139', 'gensim': '4.3.3', 'python': '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'train'}
# 2026-04-26 11:51:23,686 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=34469, vector_size=128, alpha=0.025>', 'datetime': '2026-04-26T11:51:23.686353', 'gensim': '4.3.3', 'python': '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'created'}
# 2026-04-26 11:51:23,686 : INFO : Word2Vec lifecycle event {'fname_or_handle': 'models/item_id_sg_model.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2026-04-26T11:51:23.686598', 'gensim': '4.3.3', 'python': '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'saving'}
# 2026-04-26 11:51:23,686 : INFO : not storing attribute cum_table
# 2026-04-26 11:51:23,700 : INFO : saved models/item_id_sg_model.model

# %%
model_sg = pickle.load(open(model_dir/'item_id_sg_model.model','rb'))
model_sg.wv.save(str(model_dir / 'item_id_sg.wordvectors'))
# Out:
# 2026-04-26 11:51:23,709 : INFO : KeyedVectors lifecycle event {'fname_or_handle': 'models/item_id_sg.wordvectors', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2026-04-26T11:51:23.709732', 'gensim': '4.3.3', 'python': '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]', 'platform': 'macOS-15.6.1-arm64-arm-64bit', 'event': 'saving'}
# 2026-04-26 11:51:23,719 : INFO : saved models/item_id_sg.wordvectors

# %%
# use the model above, we can use the average of embd of bought articles for customer
from sklearn.preprocessing import normalize

emb_dim = model_sg.wv.vector_size

customer_embd = np.ones((num_users, emb_dim), dtype=np.float32)/emb_dim

feed_id_seq = (
    inter.groupby('user_id')['item_id']
    .apply(list)
    .reset_index()
)

for uid, items in tqdm(feed_id_seq.values):

    valid_items = [str(i) for i in items if str(i) in model_sg.wv]
    if not valid_items:
        continue
# the user embd is the average of embds of items they bought
    vec = model_sg.wv[valid_items].mean(axis=0)

    norm = np.linalg.norm(vec)
    if norm > 0:
        vec = vec / norm

    customer_embd[int(uid)] = vec.astype(np.float32)
    
#customer_embd = normalize(customer_embd, norm="l2").astype(np.float32)
np.save(embd /'w2v_sg_user_embd.npy', customer_embd)
# Out:
# 100%|████████████████████████████████| 350008/350008 [00:03<00:00, 88315.54it/s]

# %%
w2v_sg_user_embd = np.load(embd /'w2v_sg_user_embd.npy',allow_pickle  = True)
w2v_sg_user_embd.shape
# Out:
# (1371980, 128)

# %%
# Output 2: item embd
emb_dim = model_sg.wv.vector_size

# row_number = item_id
item_embd = np.ones((num_items, emb_dim), dtype=np.float32)/emb_dim

for item_id in tqdm(range(num_items)):
    key = str(item_id)

    if key in model_sg.wv:
        vec = model_sg.wv[key]
        norm = np.linalg.norm(vec)
        if norm > 0:
            vec = vec / norm
        item_embd[item_id] = vec.astype(np.float32)
        
#item_embd = normalize(item_embd, norm="l2").astype(np.float32)
np.save(embd /'w2v_sg_item_embd.npy', item_embd)
# why L2 norm?
# Out:
# 100%|███████████████████████████████| 105542/105542 [00:00<00:00, 698495.84it/s]

# %%
w2v_sg_item_embd = np.load(embd /'w2v_sg_item_embd.npy',allow_pickle  = True)
w2v_sg_item_embd.shape
# Out:
# (105542, 128)

# %% [markdown]
# ## 3.2.2 TFIDF
# Here we used __method 1__: the description and name of artielcs and __method 2__:the interactions to apply TFIDF, then use truncatedSVD to reduce dimension

# %%
# Method 1: article description and cols with keyword "name"
import os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import numpy as np

candidate_cols = [col for col in df_art.columns if 'name' in col] + ['detail_desc']
text_cols = [col for col in candidate_cols if col in df_art.columns]

# only keep items apear in the mapping
art_text = df_art[['article_id'] + text_cols].copy()
art_text['item_id'] = art_text['article_id'].map(ARTICLE_TO_ITEM)
art_text = art_text.dropna(subset=['item_id']).copy()
art_text['item_id'] = art_text['item_id'].astype('int32')

corpus_df = art_text[['article_id', 'item_id']].copy()
corpus_df['text'] = art_text[text_cols].fillna('').astype(str).agg(' '.join, axis=1)

# TF-IDF
vectorizer = TfidfVectorizer(
    min_df=2,
    max_df=0.8,
    ngram_range=(1, 2),
    max_features=100000,
    token_pattern=r"(?u)\b\w+\b"
)
# a word should appear at least n times can be kept into the corpus,since long-tailed, this value can be set smaller
X = vectorizer.fit_transform(corpus_df['text'])
n_comp = min(128, X.shape[0] - 1, X.shape[1] - 1)

if n_comp < 1:
    raise ValueError(f"n_comp={n_comp},too few data cannot do TruncatedSVD")


svd = TruncatedSVD(n_components=n_comp, random_state=0)
X_red = svd.fit_transform(X).astype(np.float32)
X_red = normalize(X_red, norm="l2").astype(np.float32)

tfidf_item_embd1 = np.ones((num_items, n_comp), dtype=np.float32)/n_comp

for row_idx, item_id in enumerate(corpus_df['item_id'].values):
    tfidf_item_embd1[item_id] = X_red[row_idx]

np.save(embd /"tfidf_item_embd1_desc.npy", tfidf_item_embd1)

# %%
tfidf_item_embd1_desc = np.load(embd /'tfidf_item_embd1_desc.npy',allow_pickle  = True)
tfidf_item_embd1_desc.shape
# Out:
# (105542, 128)

# %% [markdown]
# Collaborative-style item representation
# Collect customer IDs according to articles, we'll create a list of customer IDs for every article. These are sentences.
# finally we will have a __sparse embd__ for every article_id (paragraph)

# %%
#Method 2 article_id - customer_id TFIDF + SVD

# only use valid_start, avoid leakage

cooc_df = embd_data[['user_id', 'item_id']].drop_duplicates().copy()
#for every item, his context is made by user_id which interacted with them.
corpus =cooc_df.groupby('item_id')['user_id'] .apply(lambda x: ' '.join(map(str, x)))

item_ids = corpus.index.to_numpy()

vectorizer = TfidfVectorizer(min_df=2, max_df=0.8,
    ngram_range=(1, 2),
    max_features=100000,
    token_pattern=r"(?u)\b\w+\b")
X = vectorizer.fit_transform(corpus)

n_comp = min(128, X.shape[0] - 1, X.shape[1] - 1)

svd = TruncatedSVD(n_components=n_comp, random_state=42)
X_svd = svd.fit_transform(X).astype(np.float32)


X_svd = normalize(X_svd, norm="l2").astype(np.float32)

tfidf_item2 = np.ones((num_items, X_svd.shape[1]), dtype=np.float32)/X_svd.shape[1]

for i, item_id in enumerate(item_ids):
    tfidf_item2[int(item_id), :] = X_svd[i, :]

np.save(embd /"tfidf_item_embd2.npy", tfidf_item2)

# %%
tfidf_item2 = np.load(embd /"tfidf_item_embd2.npy", allow_pickle=True)
tfidf_item2.shape
# Out:
# (105542, 128)

# %%
#Method 3 customer_id - product code TFIDF + SVD

cooc_df = embd_data[['user_id', 'item_id']].drop_duplicates().copy()

# every user's context is made by every item they bought
corpus = cooc_df.groupby('user_id')['item_id'].apply(lambda x: ' '.join(map(str, x)))
user_ids = corpus.index.to_numpy()

vectorizer = TfidfVectorizer(min_df=2, max_df=0.8,
    ngram_range=(1, 2),
    max_features=100000,
    token_pattern=r"(?u)\b\w+\b")
X = vectorizer.fit_transform(corpus)

n_comp_user = min(128, X.shape[0] - 1, X.shape[1] - 1)
if n_comp_user < 1:
    raise ValueError(f"n_comp_user={n_comp_user}, 数据太小，无法做 SVD")

svd = TruncatedSVD(n_components=n_comp_user, random_state=42)
X_svd = svd.fit_transform(X).astype(np.float32)

X_svd = normalize(X_svd, norm="l2").astype(np.float32)

num_users = int(df['user_id'].max()) + 1

tfidf_user_embd = np.ones((num_users, n_comp_user), dtype=np.float32)/n_comp_user

for i, user_id in enumerate(user_ids):
    tfidf_user_embd[int(user_id), :] = X_svd[i, :]

np.save(embd /"tfidf_user_embd.npy", tfidf_user_embd)

# %%
tfidf_user_embd = np.load(embd /"tfidf_user_embd.npy", allow_pickle = True)
tfidf_user_embd.shape
# Out:
# (1371980, 128)

# %%
### 2.2 Train the model with embeddings
#load pretrained embeddings
w2v_sg_user_embd = np.load(embd /'w2v_sg_user_embd.npy',allow_pickle = True)
w2v_sg_item_embd = np.load(embd /'w2v_sg_item_embd.npy',allow_pickle = True)
tfidf_user_embd = np.load(embd /'tfidf_user_embd.npy',allow_pickle = True)
tfidf_item_embd1 = np.load(embd /'tfidf_item_embd1_desc.npy',allow_pickle = True)
tfidf_item_embd2 = np.load(embd /'tfidf_item_embd2.npy',allow_pickle = True)

# %%
#prepare dense features
dense_feats =  [
    'user_hist_cnt',
    'item_hist_cnt',
    'user_price_mean',
    'item_price_mean',
    'user_item_price_gap',]

dense_cols = [c for c in dense_feats if c in train_df.columns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 9
#       1 #prepare dense features
#       2 dense_feats =  [
#       3     'user_hist_cnt',
#       4     'item_hist_cnt',
#       5     'user_price_mean',
#       6     'item_price_mean',
#       7     'user_item_price_gap',]
# ----> 9 dense_cols = [c for c in dense_feats if c in train_df.columns]
#
# NameError: name 'train_df' is not defined

# %% [markdown]
# ### 3.2.3 DNN

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import (Input, Embedding, Dense, Multiply,Lambda,Dropout, BatchNormalization, Concatenate, Flatten)
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model

train_df = pd.read_parquet("train_samples.parquet")
valid_df = pd.read_parquet("valid_samples.parquet")
train_df.head(3)
# Out:
#    user_id  item_id  window  label
# 0      107     2219       1      1
# 1      107    13042       1      1
# 2      107    17941       1      1

# %%
#train_df = train_df[ train_df['user_id'].between(0, num_users - 1) &train_df['item_id'].between(0, num_items - 1)].copy()
#valid_df = valid_df[valid_df['user_id'].between(0, num_users - 1) &valid_df['item_id'].between(0, num_items - 1)].copy()

train_df['user_idx'] = train_df['user_id'].astype('int32')
train_df['item_idx'] = train_df['item_id'].astype('int32')

valid_df['user_idx'] = valid_df['user_id'].astype('int32')
valid_df['item_idx'] = valid_df['item_id'].astype('int32')

X_train_id = train_df[['user_idx', 'item_idx']].values.astype('int32')
X_valid_id = valid_df[['user_idx', 'item_idx']].values.astype('int32')

scaler = StandardScaler()
# NN is sensitive to scale
#X_train_dense = scaler.fit_transform(train_df[dense_cols].fillna(0)).astype('float32')
#use rules from train dataset and transform
#X_valid_dense = scaler.transform(valid_df[dense_cols].fillna(0)).astype('float32')

y_train = train_df['label'].values.astype('float32')
y_valid = valid_df['label'].values.astype('float32')

print(X_train_id.shape,  y_train.shape)
print(X_valid_id.shape,  y_valid.shape)
#print(dense_cols)
# Out:
# (2795904, 2) (2795904,)
# (1282368, 2) (1282368,)

# %%
#test the shape of embeddings
print("num_users =", num_users)
print("num_items =", num_items)

for name, arr in [
    ("w2v_sg_user_embd", w2v_sg_user_embd),
    ("tfidf_user_embd", tfidf_user_embd),
    ("w2v_sg_item_embd", w2v_sg_item_embd),
    ("tfidf_item_embd1", tfidf_item_embd1),
    ("tfidf_item_embd2", tfidf_item_embd2),
]:
    arr = np.asarray(arr)
    print(name, "shape=", arr.shape, "dtype=", arr.dtype, "ndim=", arr.ndim)

assert np.asarray(w2v_sg_user_embd).shape[0] == num_users
assert np.asarray(tfidf_user_embd).shape[0] == num_users
assert np.asarray(w2v_sg_item_embd).shape[0] == num_items
assert np.asarray(tfidf_item_embd1).shape[0] == num_items
assert np.asarray(tfidf_item_embd2).shape[0] == num_items
# Out:
# num_users = 1371980
# num_items = 105542
# w2v_sg_user_embd shape= (1371980, 128) dtype= float32 ndim= 2
# tfidf_user_embd shape= (1371980, 128) dtype= float32 ndim= 2
# w2v_sg_item_embd shape= (105542, 128) dtype= float32 ndim= 2
# tfidf_item_embd1 shape= (105542, 128) dtype= float32 ndim= 2
# tfidf_item_embd2 shape= (105542, 128) dtype= float32 ndim= 2

# %%
item_embd_outside = np.load("w2v_skipgram_item_embd.npy", allow_pickle = True)
item_embd_outside.shape
# Out:
# (105543, 128)

# %%
def dnn_w2v_only(
    w2v_sg_user_embd,
    w2v_sg_item_embd,
    trainable_emb=False
):
    id_input = Input(shape=(2,), dtype=tf.int32, name="id_input")

    user_idx = Lambda(lambda x: x[:, 0], name="user_idx")(id_input)
    item_idx = Lambda(lambda x: x[:, 1], name="item_idx")(id_input)

    user_embd_layer_1 = Embedding(
        input_dim=w2v_sg_user_embd.shape[0],
        output_dim=w2v_sg_user_embd.shape[1],
        weights=[w2v_sg_user_embd],
        trainable=trainable_emb,
        name="w2v_sg_user_embd"
    )

    item_embd_layer_1 = Embedding(
        input_dim=w2v_sg_item_embd.shape[0],
        output_dim=w2v_sg_item_embd.shape[1],
        weights=[w2v_sg_item_embd],
        trainable=trainable_emb,
        name="w2v_sg_item_embd"
    )

    u1 = Flatten()(user_embd_layer_1(user_idx))
    i1 = Flatten()(item_embd_layer_1(item_idx))

    u1p = Dense(64, activation=None, name="u1_proj")(u1)
    i1p = Dense(64, activation=None, name="i1_proj")(i1)

    inter_11 = Multiply(name="u1_i1_mul")([u1p, i1p])

   # x_id = Concatenate(axis=-1)([u1p,i1p,inter_11])
    x_id = Concatenate(axis=-1)([u1, i1])

    x0 = BatchNormalization()(x_id)

    x = Dropout(0.2)(x0)
    x = Dense(256, activation="swish")(x)
    x = Dropout(0.2)(x)

    x = Dense(128, activation="swish")(x)
    x = Dropout(0.2)(x)

    x = Concatenate(axis=-1)([x, x0])
    x = Dropout(0.2)(x)

    out = Dense(1, activation="sigmoid")(x)

    model = Model(inputs=id_input, outputs=out)
    return model

# %%
model_dnn_w2v_only = dnn_w2v_only(
    w2v_sg_user_embd=w2v_sg_user_embd,
    w2v_sg_item_embd=w2v_sg_item_embd,
    trainable_emb=False
)

model_dnn_w2v_only.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss="binary_crossentropy",
    metrics=[
        tf.keras.metrics.AUC(name="auc"),
        tf.keras.metrics.BinaryAccuracy(name="acc")])

#model.summary()

# %%
callbacks = [tf.keras.callbacks.EarlyStopping(
        monitor="val_auc",
        mode="max",
        patience=1,
        restore_best_weights=True)]

history = model_dnn_w2v_only.fit(X_train_id,y_train,
    validation_data=(X_valid_id, y_valid),
    epochs=5,
    batch_size=4096,
    callbacks=callbacks,
    verbose=1)
# Out:
# Epoch 1/5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - acc: 0.8575 - auc: 0.8752 - loss: 0.3073 - val_acc: 0.7532 - val_auc: 0.7138 - val_loss: 0.5372
# Epoch 2/5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 12s 17ms/step - acc: 0.8988 - auc: 0.9363 - loss: 0.2269 - val_acc: 0.7591 - val_auc: 0.5745 - val_loss: 0.8828

# %% [markdown]
# ### model 2: dnn_w2v_tfidf_emb

# %%
def dnn_w2v_tfidf_emb(
    w2v_sg_user_embd,
    w2v_sg_item_embd,
    item_embd,
    trainable_emb=False,
    proj_dim=64
):
    id_input = Input(shape=(2,), dtype=tf.int32, name="id_input")

    user_idx = Lambda(lambda x: x[:, 0], name="user_idx")(id_input)
    item_idx = Lambda(lambda x: x[:, 1], name="item_idx")(id_input)

    u_w2v_layer = Embedding(
        input_dim=w2v_sg_user_embd.shape[0],
        output_dim=w2v_sg_user_embd.shape[1],
        weights=[w2v_sg_user_embd],
        trainable=trainable_emb,
        name="w2v_sg_user_embd"
    )

    i_w2v_layer = Embedding(
        input_dim=w2v_sg_item_embd.shape[0],
        output_dim=w2v_sg_item_embd.shape[1],
        weights=[w2v_sg_item_embd],
        trainable=trainable_emb,
        name="w2v_sg_item_embd"
    )

    i_text_layer = Embedding(
        input_dim= item_embd.shape[0],
        output_dim=item_embd.shape[1],
        weights=[item_embd],
        trainable=trainable_emb,
        name="item_embd"
    )

    u_w2v = Flatten()(u_w2v_layer(user_idx))
    i_w2v = Flatten()(i_w2v_layer(item_idx))
    i_text = Flatten()(i_text_layer(item_idx))

    #u_w2v_p = Dense(proj_dim, activation=None, name="u_w2v_proj")(u_w2v)
    #i_w2v_p = Dense(proj_dim, activation=None, name="i_w2v_proj")(i_w2v)
    #i_text_p = Dense(proj_dim, activation=None, name="i_text_proj")(i_text)

    
    #x_id = Concatenate(axis=-1)([u_w2v_p,i_w2v_p,i_text_p,])
    x_id = Concatenate(axis=-1)([u_w2v,i_w2v,i_text,])
    x0 = BatchNormalization()(x_id)

    x = Dropout(0.35)(x0)
    x = Dense(256,
        activation="relu",
        kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)

    x = Dropout(0.35)(x)
    x = Dense(64,
        activation="relu",
        kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)

    x = Dropout(0.2)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model(inputs=id_input, outputs=out)
    return model

# %%
model_2 = dnn_w2v_tfidf_emb(
    w2v_sg_user_embd=w2v_sg_user_embd,
    w2v_sg_item_embd=w2v_sg_item_embd,
    item_embd=tfidf_item_embd1,
    trainable_emb=False,
    proj_dim=64
)

model_2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.AUC(name="auc")]
)

callbacks = [tf.keras.callbacks.EarlyStopping(
        monitor="val_auc",
        mode="max",
        patience=0,
        restore_best_weights=True)]

history = model_2.fit(
    X_train_id,
    y_train,
    validation_data=(X_valid_id, y_valid),
    epochs=5,
    batch_size=4096,
    callbacks=callbacks
)
# Out:
# Epoch 1/5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - auc: 0.8503 - loss: 0.3324 - val_auc: 0.7600 - val_loss: 0.4363
# Epoch 2/5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - auc: 0.9028 - loss: 0.2793 - val_auc: 0.6906 - val_loss: 0.5546

# %% [markdown]
# ### model 3 multi embd

# %%
def dnn_multi_emb_wo_dense(
    w2v_sg_user_embd,
    tfidf_user_embd,
    w2v_sg_item_embd,
    tfidf_item_embd1,
    tfidf_item2,
    trainable_emb=False,
    proj_dim=64):
    
    id_input = Input(shape=(2,), dtype=tf.int32, name="id_input")

    user_idx = Lambda(lambda x: x[:, 0], name="user_idx")(id_input)
    item_idx = Lambda(lambda x: x[:, 1], name="item_idx")(id_input)

    u_w2v_layer = Embedding(
        input_dim=w2v_sg_user_embd.shape[0],
        output_dim=w2v_sg_user_embd.shape[1],
        weights=[w2v_sg_user_embd],
        trainable=trainable_emb,
        name="w2v_sg_user_embd")    
    u_tfidf_layer = Embedding(
        input_dim=tfidf_user_embd.shape[0],
        output_dim=tfidf_user_embd.shape[1],
        weights=[tfidf_user_embd],
        trainable=trainable_emb,
        name="tfidf_user_embd")

    i_w2v_layer = Embedding(
        input_dim=w2v_sg_item_embd.shape[0],
        output_dim=w2v_sg_item_embd.shape[1],
        weights=[w2v_sg_item_embd],
        trainable=trainable_emb,
        name="w2v_sg_item_embd")

    i_text_layer = Embedding(
        input_dim=tfidf_item_embd1.shape[0],
        output_dim=tfidf_item_embd1.shape[1],
        weights=[tfidf_item_embd1],
        trainable=trainable_emb,
        name="tfidf_item_embd1")

    i_collab_layer = Embedding(
        input_dim=tfidf_item2.shape[0],
        output_dim=tfidf_item2.shape[1], weights=[tfidf_item2],
        trainable=trainable_emb,
        name="tfidf_item2")

    u_w2v = Flatten()(u_w2v_layer(user_idx))
    u_tfidf = Flatten()(u_tfidf_layer(user_idx))

    i_w2v = Flatten()(i_w2v_layer(item_idx))
    i_text = Flatten()(i_text_layer(item_idx))
    i_collab = Flatten()(i_collab_layer(item_idx))

    u_w2v_p = Dense(proj_dim, activation=None, name="u_w2v_proj")(u_w2v)
    u_tfidf_p = Dense(proj_dim, activation=None, name="u_tfidf_proj")(u_tfidf)

    i_w2v_p = Dense(proj_dim, activation=None, name="i_w2v_proj")(i_w2v)
    i_text_p = Dense(proj_dim, activation=None, name="i_text_proj")(i_text)
    i_collab_p = Dense(proj_dim, activation=None, name="i_collab_proj")(i_collab)    
   # x_id = Concatenate(axis=-1)([u_w2v_p,u_tfidf_p,i_w2v_p,i_text_p,i_collab_p,])
    x_id = Concatenate(axis=-1)([u_w2v,u_tfidf,i_w2v,i_text,i_collab])

    x0 = BatchNormalization()(x_id)

    x = Dropout(0.35)(x0)
    x = Dense(256,
        activation="relu",
        kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)

    x = Dropout(0.35)(x)
    x = Dense(64,activation="relu",kernel_regularizer=tf.keras.regularizers.l2(1e-5))(x)

    x = Dropout(0.25)(x)

    out = Dense(1, activation="sigmoid")(x)

    model = Model(inputs=id_input, outputs=out)
    return model

# %%
model_3 = dnn_multi_emb_wo_dense(
    w2v_sg_user_embd=w2v_sg_user_embd,
    tfidf_user_embd=tfidf_user_embd,
    w2v_sg_item_embd=w2v_sg_item_embd,
    tfidf_item_embd1=tfidf_item_embd1,
    tfidf_item2=tfidf_item2,
    trainable_emb=False,
    proj_dim=64
)

model_3.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.AUC(name="auc")]
)

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_auc",
        mode="max",
        patience=1,
        restore_best_weights=True
    )
]

# %%
history = model_3.fit(X_train_id,y_train,
    validation_data=(X_valid_id, y_valid),
    epochs=5,
    batch_size=4096,
    callbacks=callbacks,
    verbose=1)
# Out:
# Epoch 1/5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - auc: 0.8546 - loss: 0.3306 - val_auc: 0.7654 - val_loss: 0.4370
# Epoch 2/5
# 683/683 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - auc: 0.9020 - loss: 0.2808 - val_auc: 0.7022 - val_loss: 0.5467

# %% [markdown]
# ## 4. Evaluation Functions and Output

# %%
def apk(actual, predicted, k=12):
    actual = list(actual)
    predicted = list(predicted)[:k]

    if len(actual) == 0:
        return 0.0

    score = 0.0
    hits = 0.0
    used = set()

    for i, p in enumerate(predicted, start=1):
        if p in actual and p not in used:
            hits += 1.0
            score += hits / i
            used.add(p)

    return score / min(len(actual), k)

def mapk(user_true_dict, user_pred_dict, k=12):
    if not user_true_dict:
        return 0.0
    return float(np.mean([
        apk(user_true_dict[u], user_pred_dict.get(u, []), k)
        for u in user_true_dict
    ]))

# %% [markdown]
# ## 5. Results and Analysis

# %%
K = 12

valid_start = pd.Timestamp("2020-09-16")
valid_end = valid_start + pd.Timedelta(days=7)

valid_history = df_small[df_small["t_dat"] < valid_start].copy()

valid_label = df_small[
    (df_small["t_dat"] >= valid_start) &
    (df_small["t_dat"] < valid_end)
].copy()

user_true_dict = (
    valid_label[["user_id", "item_id"]]
    .drop_duplicates(["user_id", "item_id"])
    .groupby("user_id")["item_id"]
    .apply(list)
    .to_dict()
)

valid_cand_compare = (
    itemcf(valid_history, topk=50)[["user_id", "item_id", "score"]]
    .drop_duplicates(["user_id", "item_id"])
    .rename(columns={"score": "itemcf_score"})
    .reset_index(drop=True)
)

itemcf_top12 = (
    valid_cand_compare
    .sort_values(["user_id", "itemcf_score"], ascending=[True, False])
    .groupby("user_id")
    .head(K)
)

itemcf_pred_dict = (
    itemcf_top12
    .groupby("user_id")["item_id"]
    .apply(list)
    .to_dict()
)

map12_itemcf = mapk(user_true_dict, itemcf_pred_dict, k=K)
print("ItemCF only MAP@12:", map12_itemcf)
# Out:
# Build ItemCF: 350008it [00:12, 28902.79it/s]
# Recall ItemCF: 350008it [00:32, 10899.30it/s]
# ItemCF only MAP@12: 0.00853421199042284

# %%
valid_cand_w2v = valid_cand_compare.copy()

X_valid_cand_id = valid_cand_w2v[["user_id", "item_id"]].values.astype("int32")

valid_cand_w2v["dnn_w2v_only_score"] = model_dnn_w2v_only.predict(
    X_valid_cand_id,
    batch_size=8192,
    verbose=1
).ravel()

dnn_w2v_only_top12 = (
    valid_cand_w2v
    .sort_values(["user_id", "dnn_w2v_only_score"], ascending=[True, False])
    .groupby("user_id")
    .head(K)
)

dnn_w2v_only_pred_dict = (
    dnn_w2v_only_top12
    .groupby("user_id")["item_id"]
    .apply(list)
    .to_dict()
)

dnn_w2v_only_pred_dict = {
    u: dnn_w2v_only_pred_dict.get(u, [])
    for u in user_true_dict.keys()
}

map12_dnn_w2v_only = mapk(user_true_dict, dnn_w2v_only_pred_dict, k=K)

print("DNN w2v-only MAP@12:", map12_dnn_w2v_only)
# Out:
# 2129/2129 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step
# DNN w2v-only MAP@12: 0.011456807247362255

# %%
valid_cand_model2 = valid_cand_compare.copy()

valid_cand_model2["dnn_score_2"] = model_2.predict(
    X_valid_cand_id,
    batch_size=8192,
    verbose=1
).ravel()

dnn_model2_top12 = (
    valid_cand_model2
    .sort_values(["user_id", "dnn_score_2"], ascending=[True, False])
    .groupby("user_id")
    .head(K)
)

dnn_2_pred_dict = (dnn_model2_top12.groupby("user_id")["item_id"] .apply(list).to_dict())

map12_dnn_model2 = mapk(user_true_dict, dnn_2_pred_dict, k=K)
print('w2v + tfidf item',map12_dnn_model2)
# Out:
# 2129/2129 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step
# w2v + tfidf item 0.009208492478550585

# %%
valid_cand_model3 = valid_cand_compare.copy()

X_valid_cand_id = valid_cand_model3[["user_id", "item_id"]].values.astype("int32")

valid_cand_model3["dnn_score_3"] = model_3.predict(
    X_valid_cand_id,
    batch_size=8192,
    verbose=1
).ravel()

dnn_model3_top12 = (valid_cand_model3.sort_values(["user_id", "dnn_score_3"], ascending=[True, False])
    .groupby("user_id").head(K))

dnn_3_pred_dict = (dnn_model3_top12.groupby("user_id")["item_id"].apply(list).to_dict())

dnn_3_pred_dict = {u: dnn_3_pred_dict.get(u, [])for u in user_true_dict.keys()}

map12_dnn_model3 = mapk(user_true_dict, dnn_3_pred_dict, k=K)

print("all embeddings MAP@12:", map12_dnn_model3)
# Out:
# 2129/2129 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step
# all embeddings MAP@12: 0.009031926063648481

# %%
print("ItemCF only MAP@12:", map12_itemcf)
print('----------')
print("DNN_w2v_only_embd rerank MAP@12:", map12_dnn_w2v_only)
print('----------')
print("DNN_w2v + tfidf_3_embd rerank MAP@12:", map12_dnn_model2)
print('----------')
print("DNN_multi_embd rerank MAP@12:", map12_dnn_model3)
# Out:
# ItemCF only MAP@12: 0.00853421199042284
# ----------
# DNN_w2v_only_embd rerank MAP@12: 0.011456807247362255
# ----------
# DNN_w2v + tfidf_3_embd rerank MAP@12: 0.009208492478550585
# ----------
# DNN_multi_embd rerank MAP@12: 0.009031926063648481

# %%
import matplotlib.pyplot as plt

results = pd.DataFrame({
    "Model": [
        "ItemCF only",
        "DNN w2v only",
        "DNN w2v + tfidf",
        "DNN multi emb"
    ],
    "MAP@12": [
        map12_itemcf,
        map12_dnn_w2v_only,
        map12_dnn_model2,
        map12_dnn_model3
    ]
})
plt.figure(figsize=(8, 5))

plt.bar(results["Model"], results["MAP@12"])

plt.xticks(rotation=30)
plt.ylabel("MAP@12")
plt.title("Model Comparison")

for i, v in enumerate(results["MAP@12"]):
    plt.text(i, v + 0.0002, f"{v:.4f}", ha="center")

plt.show()

# %% [markdown]
# Why the TFIDF methods here we used is better than in Project stage 2(the psudo text is a combination of "description","group name") etc.?
# If we directly use embeddings for similarity calculation and recommend, the MAP@K seems worse than our Item-CF baseline

# %% [markdown]
# ## 6 Limitation and Future work

# %% [markdown]
# Due to time constraints, this work does not fully utilize the entire user behavior sequences. Instead, only a limited history window is used, which may miss long-term user preferences.
#
# In addition, the train/validation split is relatively simple and does not fully simulate a realistic online recommendation setting. More refined data splitting strategies (e.g., stricter temporal splits) could lead to more reliable evaluation.

# %% [markdown]
# Future work could explore using LightGBM for reranking, as it is well-suited for combining heterogeneous features such as itemCF scores and user/item statistics. Compared to DNNs, it may better capture feature interactions and improve MAP@K.
#
# Additionally, more advanced models could be considered, such as sequence-based methods (e.g., SASRec) to better model user behavior over time.
#
# Finally, improving negative sampling (e.g., using hard negatives) may help align training with the ranking objective and further enhance performance.
#
# Our results suggest that increasing model complexity does not necessarily improve performance, highlighting the importance of feature design and training strategy.

# %% [markdown]
# ## 7. Appendix

# %%
def add_5emb_lgb_features(
    df,
    w2v_sg_user_embd,
    tfidf_user_embd,
    w2v_sg_item_embd,
    tfidf_item_embd1,
    tfidf_item2):
    
    df = df.copy()

    user_ids = df["user_id"].values.astype("int32")
    item_ids = df["item_id"].values.astype("int32")

    u_w2v = w2v_sg_user_embd[user_ids]
    u_tfidf = tfidf_user_embd[user_ids]

    i_w2v = w2v_sg_item_embd[item_ids]
    i_text = tfidf_item_embd1[item_ids]
    i_collab = tfidf_item2[item_ids]

    # w2v user-item interaction
    df["u_w2v_i_w2v_dot"] = np.sum(u_w2v * i_w2v, axis=1)
    #df["u_w2v_i_w2v_l2"] = np.linalg.norm(u_w2v - i_w2v, axis=1)
    
    # tfidf user-item collaborative interaction
    if u_tfidf.shape[1] == i_collab.shape[1]:
        pass
        #df["u_tfidf_i_collab_dot"] = np.sum(u_tfidf * i_collab, axis=1)
        #df["u_tfidf_i_collab_l2"] = np.linalg.norm(u_tfidf - i_collab, axis=1)
        #df["i_collab_mean"] = np.mean(np.abs(u_tfidf - i_collab), axis=1)

    # item embedding statistics
    df["i_text_mean"] = np.mean(i_text, axis=1)
    df["i_collab_mean"] = np.mean(i_collab, axis=1)

    return df

# %%
def add_lgb_2_features(df, w2v_sg_user_embd, w2v_sg_item_embd):
    df = df.copy()

    user_ids = df["user_id"].values.astype("int32")
    item_ids = df["item_id"].values.astype("int32")

    u_vec = w2v_sg_user_embd[user_ids]
    i_vec = w2v_sg_item_embd[item_ids]

    df["u_w2v_i_w2v_dot"] = np.sum(u_vec * i_vec, axis=1).astype("float32")
    df["u_w2v_i_w2v_l2"] = np.linalg.norm(u_vec - i_vec, axis=1).astype("float32")

    return df

# %%
feature_cols = [
    "u_w2v_i_w2v_dot",
    "u_w2v_i_w2v_l2"
]

train_lgb = add_lgb_2_features(train_samples, w2v_sg_user_embd, w2v_sg_item_embd)
valid_lgb = add_lgb_2_features(valid_samples, w2v_sg_user_embd, w2v_sg_item_embd)

feature_cols = ["u_w2v_i_w2v_dot", "u_w2v_i_w2v_l2"]

for c in feature_cols:
    train_lgb[c] = train_lgb[c].astype("float32")
    valid_lgb[c] = valid_lgb[c].astype("float32")

train_lgb["label"] = train_lgb["label"].astype("int8")
valid_lgb["label"] = valid_lgb["label"].astype("int8")

# %%
import lightgbm as lgb

# %%
for c in feature_cols:
    train_lgb[c] = train_lgb[c].astype("float32")
    valid_lgb[c] = valid_lgb[c].astype("float32")

train_lgb["label"] = train_lgb["label"].astype("int8")
valid_lgb["label"] = valid_lgb["label"].astype("int8")

# %%
train_lgb_small = train_lgb.sample(50000, random_state=42)
valid_lgb_small = valid_lgb.sample(20000, random_state=42)

# %%
# 先抽样跑通

lgb_model = lgb.LGBMClassifier(
    objective="binary",
    n_estimators=100,
    learning_rate=0.05,
    num_leaves=31,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    n_jobs=4,
    random_state=42
)

# %%
lgb_model.fit(
    train_lgb_small[feature_cols],
    train_lgb_small["label"],
    eval_set=[(valid_lgb_small[feature_cols], valid_lgb_small["label"])],
    eval_metric="auc",
    callbacks=[
        lgb.early_stopping(stopping_rounds=30),
        lgb.log_evaluation(period=50)
    ]
)

# %% [markdown]
# github link:

# %% [markdown]
# Resouce Declaration
